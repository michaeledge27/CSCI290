# %% [markdown]
# <a href="https://colab.research.google.com/github/michaeledge27/CSCI290/blob/main/notebooks/Centroids.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
iris = load_iris()

# %%
df = pd.DataFrame( iris.data, columns = iris.feature_names)

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df["species"] = iris.target

# %%
target_names = {      # switching to 0, 1, 2 for convenience
    0:'setosa',
    1:'versicolor',
    2:'virginica'
}

df['species_name'] = df['species'].map(target_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species species_name
# 0        0       setosa
# 1        0       setosa
# 2        0       setosa
# 3        0       setosa
# 4        0       setosa

# %%
plt.figure(figsize=(5, 3))
sns.scatterplot( x = "petal length (cm)", y = "petal width (cm)", data = df, hue = "species_name");

# %%
# find the averages of the petal lengths (x's) and the petal widths (y's) for each of the species
centroids = df.groupby("species_name")[["petal length (cm)", "petal width (cm)"]].mean()

# %%
centroids
# Out:
#               petal length (cm)  petal width (cm)
# species_name
# setosa                    1.462             0.246
# versicolor                4.260             1.326
# virginica                 5.552             2.026

# %%
centroids.loc["versicolor"]
# Out:
# petal length (cm)    4.260
# petal width (cm)     1.326
# Name: versicolor, dtype: float64

# %%
plt.figure(figsize=(5, 3))
sns.scatterplot( x = "petal length (cm)", y = "petal width (cm)", data = df, hue = "species_name")
sns.scatterplot( x = "petal length (cm)", y = "petal width (cm)", data = centroids, c = "black", marker="X", s = 100);
